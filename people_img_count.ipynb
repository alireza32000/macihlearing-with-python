# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# !pip install easyocr
# !pip install imutils
# !pip install cv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (5,656 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
import imutils
import easyocr
import pytesseract
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
from google.colab.patches import cv2_imshow

# %%
people_img= cv.imread("/content/1684734031000.jpg")
people_img = cv.imread("/content/1684734031000.jpg",1)
plt.imshow(cv.cvtColor(people_img, cv.COLOR_BGR2RGB));
plt.imshow(cv.cvtColor(people_img, cv.COLOR_BGR2RGB));

# %%
reader = easyocr.Reader(['en'])

# %% [markdown]
# #plate detection

# %% [markdown]
# Apply bilater filter for Noise reduction and find edges

# %%
# Define the variable and assign the correct value
man_woman_count = 26
people_img_info_man_woman_count = ("/content/1684734031000.jpg", man_woman_count)
print(man_woman_count)
# Out:
# 26
